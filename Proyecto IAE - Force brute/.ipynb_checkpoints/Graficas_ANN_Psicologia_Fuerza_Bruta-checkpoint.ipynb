# %% [markdown]
# # Graficación de la explicando ANN (Clasificación) para identificar depresión por fuerza bruta

# %% [markdown]
# ## Preparación de los datos

# %% [markdown]
# Lectura de los datos de acuerdo al dataset de metricas

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv("Dataset_QS_METRICS.csv")

# %% [markdown]
# Ordenación de los datos de acuerdo a la metrica de importancia

# %%
df_a = df.sort_values(by = "Acurracy global", ascending = False)
df_p0 = df.sort_values(by = "Precision_0", ascending = False)
df_p1 = df.sort_values(by = "Precision_1", ascending = False)
df_p2 = df.sort_values(by = "Precision_2", ascending = False)
df_r0 = df.sort_values(by = "Recall_0", ascending = False)
df_r1 = df.sort_values(by = "Recall_1", ascending = False)
df_r2 = df.sort_values(by = "Recall_2", ascending = False)
df_f0 = df.sort_values(by = "F1_score_0", ascending = False)
df_f1 = df.sort_values(by = "F1_score_1", ascending = False)
df_f2 = df.sort_values(by = "F1_score_2", ascending = False)

# %% [markdown]
# ## Generación de los gráficos a partir de los datos

# %% [markdown]
# Visualización de la gráfica de accurracy global con ordenación

# %%
import matplotlib.pyplot as plt

eje_x = df_a.iloc[:, 0].to_numpy().tolist()
eje_y = df_a.iloc[:, 1].to_numpy().tolist()

labels=['Accuracy global']
fig, ax = plt.subplots()

ax.set_yticks(range(len(eje_x)),eje_x)
ax.barh(range(len(eje_y)), eje_y, color = 'tab:purple')

for i,n in enumerate(eje_y):
    ax.text( n- 6, i - 0.18, n, ha='center', va='bottom', color = 'white')
    
plt.legend(labels)

# ax.grid(axis = 'y', color = 'gray', linestyle = 'dashed')
ax.set_title('Accuracy global', loc = "left", fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
fig.set_size_inches(15, 45)
plt.show()

# %% [markdown]
# ### Graficas de la clase Low

# %% [markdown]
# Visualización de la gráfica de precision con ordenación

# %%
import matplotlib.pyplot as plt

fig = None
ax = None

eje_x = df_p0.iloc[:, 0].to_numpy().tolist()
eje_y = df_p0.iloc[:, 2].to_numpy().tolist()

labels=['Precision']
fig, ax = plt.subplots()

ax.set_xticks(range(len(eje_x)),eje_x)
ax.bar(range(len(eje_y)), eje_y, color = 'tab:purple')

for i,n in enumerate(eje_y):
    ax.text( i, n + 0.01, n, ha='center', rotation=270, va='bottom', color = 'black')
    
plt.legend(labels)

# ax.grid(axis = 'y', color = 'gray', linestyle = 'dashed')
ax.set_title('Precision', loc = "left", fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
fig.set_size_inches(35, 20)
plt.show()

# %% [markdown]
# Visualización de la gráfica de recall con ordenación

# %% [markdown]
# Visualización de la gráfica de f1_score con ordenación

# %%
import matplotlib.pyplot as plt

eje_x = df_a.iloc[:, 0].to_numpy().tolist()
eje_y = df_a.iloc[:, 1].to_numpy().tolist()

labels=['Accuracy global']
fig, ax = plt.subplots()

ax.set_xticks(range(len(eje_x)),eje_x)
ax.plot(range(len(eje_y)), eje_y, marker = 'o', color = 'tab:purple')
    
plt.legend(labels)

# ax.grid(axis = 'y', color = 'gray', linestyle = 'dashed')
ax.set_title('Accuracy global', loc = "left", fontdict = {'fontsize':14, 'fontweight':'bold', 'color':'tab:blue'})
fig.set_size_inches(30, 10)
plt.show()

# %%
eje_x
# Out:
# [3,
#  62,
#  74,
#  102,
#  93,
#  32,
#  55,
#  59,
#  67,
#  86,
#  70,
#  99,
#  12,
#  65,
#  4,
#  37,
#  30,
#  29,
#  94,
#  58,
#  6,
#  7,
#  8,
#  50,
#  21,
#  39,
#  40,
#  80,
#  16,
#  47,
#  34,
#  2,
#  49,
#  51,
#  57,
#  54,
#  101,
#  44,
#  71,
#  100,
#  78,
#  90,
#  45,
#  52,
#  43,
#  35,
#  9,
#  17,
#  18,
#  27,
#  31,
#  19,
#  36,
#  38,
#  33,
#  88,
#  83,
#  46,
#  85,
#  15,
#  98,
#  79,
#  24,
#  63,
#  89,
#  76,
#  77,
#  28,
#  5,
#  82,
#  81,
#  48,
#  96,
#  95,
#  14,
#  91,
#  92,
#  87,
#  13,
#  75,
#  72,
#  20,
#  97,
#  69,
#  68,
#  66,
#  64,
#  25,
#  61,
#  10,
#  26,
#  11,
#  41,
#  1,
#  73,
#  23,
#  60,
#  22,
#  42,
#  53,
#  84,
#  56]

# %%
eje_y
# Out:
# [66.66666666666666,
#  66.66666666666666,
#  66.66666666666666,
#  64.1025641025641,
#  64.1025641025641,
#  64.1025641025641,
#  64.1025641025641,
#  64.1025641025641,
#  64.1025641025641,
#  64.1025641025641,
#  64.1025641025641,
#  64.1025641025641,
#  61.53846153846154,
#  61.53846153846154,
#  61.53846153846154,
#  61.53846153846154,
#  61.53846153846154,
#  61.53846153846154,
#  61.53846153846154,
#  61.53846153846154,
#  61.53846153846154,
#  61.53846153846154,
#  61.53846153846154,
#  61.53846153846154,
#  61.53846153846154,
#  61.53846153846154,
#  61.53846153846154,
#  61.53846153846154,
#  61.53846153846154,
#  61.53846153846154,
#  61.53846153846154,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  58.97435897435898,
#  56.41025641025641,
#  56.41025641025641,
#  56.41025641025641,
#  56.41025641025641,
#  56.41025641025641,
#  56.41025641025641,
#  56.41025641025641,
#  56.41025641025641,
#  56.41025641025641,
#  56.41025641025641,
#  56.41025641025641,
#  56.41025641025641,
#  56.41025641025641,
#  56.41025641025641,
#  56.41025641025641,
#  56.41025641025641,
#  53.84615384615385,
#  53.84615384615385,
#  53.84615384615385,
#  53.84615384615385,
#  53.84615384615385,
#  53.84615384615385,
#  53.84615384615385,
#  53.84615384615385,
#  53.84615384615385,
#  53.84615384615385,
#  53.84615384615385,
#  53.84615384615385,
#  53.84615384615385,
#  53.84615384615385,
#  53.84615384615385,
#  53.84615384615385,
#  53.84615384615385,
#  53.84615384615385,
#  53.84615384615385,
#  53.84615384615385,
#  53.84615384615385,
#  51.28205128205128,
#  51.28205128205128,
#  51.28205128205128,
#  51.28205128205128,
#  51.28205128205128,
#  51.28205128205128,
#  48.71794871794872,
#  48.71794871794872,
#  48.71794871794872,
#  46.15384615384615,
#  43.58974358974359]
